# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#Read the data to a dataframe
data = pd.read_csv('synthetic_customer_data.csv')

# %%
#We have a distribution plot for Age, annual income and Spending score

plt.figure(1, figsize=(15,6))
n=0
for x in ['Age', 'AnnualIncome', 'SpendingScore']:
    n+=1
    plt.subplot(1, 3, n)
    plt.subplots_adjust(hspace =0.5, wspace=0.5)
    sns.distplot(data[x], bins=20)
    plt.title('Distplot of {}'.format(x))
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18064\164898278.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[x], bins=20)
# C:\Users\HP\AppData\Local\Temp\ipykernel_18064\164898278.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[x], bins=20)
# C:\Users\HP\AppData\Local\Temp\ipykernel_18064\164898278.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[x], bins=20)

# %%
# plt.figure(1, figsize=(15,6))
# n=0
# for x in ['Age', 'AnnualIncome', 'SpendingScore']:
#     n+=1
#     plt.subplot(1, 3, n)
#     plt.subplots_adjust(hspace =0.5, wspace=0.5)
#     sns.histplot(data[x], bins=20)
#     plt.title('Histplot of {}'.format(x))
# plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='Gender', data= data)
plt.show()

# %%
plt.figure(1, figsize=(15,7))
n=0
for cols in ['Age', 'AnnualIncome','SpendingScore']:
    n+=1
    plt.subplot(1, 3, n)
    sns.set(style='whitegrid')
    plt.subplots_adjust(hspace =0.5, wspace=0.5)
    sns.violinplot(x=cols, y='Gender', data=data)
    plt.ylabel('Gender' if n==1 else '')
    plt.title('Violin Plot')
plt.show()

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'AnnualIncome', 'SpendingScore'], dtype='object')

# %%
data.head
# Out:
# <bound method NDFrame.head of      CustomerID  Gender  Age  AnnualIncome  SpendingScore
# 0             1    Male   38         81886             57
# 1             2  Female   49         95745             26
# 2             3    Male   40        103251             41
# 3             4    Male   50        114456             35
# 4             5    Male   20         73413             63
# ..          ...     ...  ...           ...            ...
# 495         496    Male   35         76264             62
# 496         497    Male   47         95060             93
# 497         498  Female   32        117416             58
# 498         499    Male   44         77545             67
# 499         500  Female   68        138195             56
#
# [500 rows x 5 columns]>
